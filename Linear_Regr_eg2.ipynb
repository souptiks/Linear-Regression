# %% [markdown]
# <a href="https://colab.research.google.com/github/souptiks/Linear-Regression/blob/main/Linear_Regr_eg2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('train.csv')
df
# Out:
#         x          y
# 0    24.0  21.549452
# 1    50.0  47.464463
# 2    15.0  17.218656
# 3    38.0  36.586398
# 4    87.0  87.288984
# ..    ...        ...
# 695  58.0  58.595006
# 696  93.0  94.625094
# 697  82.0  88.603770
# 698  66.0  63.648685
# 699  97.0  94.975266
#
# [700 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.xlabel('x',fontsize='10')
plt.ylabel('y',fontsize = '10')
plt.scatter(df.x,df.y,color = 'red',marker ='+')
plt.show()

# %%
import numpy as np
reg = linear_model.LinearRegression()
input_data1 = np.array(df.x).reshape(-1,1)
input_data2 = np.array(df.x).reshape(-1,1)
reg.fit(input_data1,input_data2)
# Out:
# LinearRegression()

# %%
df1 = pd.read_csv('test.csv')

# %%
p = reg.predict(df1)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(

# %%
df1['y'] = p
df1
# Out:
#       x     y
# 0    77  77.0
# 1    21  21.0
# 2    22  22.0
# 3    20  20.0
# 4    36  36.0
# ..   ..   ...
# 295  71  71.0
# 296  46  46.0
# 297  55  55.0
# 298  62  62.0
# 299  47  47.0
#
# [300 rows x 2 columns]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
input_data = np.array(df.x).reshape(-1, 1)
plt.xlabel('x',fontsize='20')
plt.ylabel('y',fontsize = '20')
plt.scatter(df.x,df.y,color = 'red',marker = '+')
plt.plot(df.x,reg.predict(input_data1),color = 'blue')
plt.show()
